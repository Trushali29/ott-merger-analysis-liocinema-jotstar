# %%
# install sqlalchemy
# !pip install sqlalchemy

# %%
import mysql.connector
from sqlalchemy import create_engine 
import pandas as pd
import numpy as np

# %% [markdown]
# Create two engines for two databases - create a database in mysql as name jotstar_db and liocinema_db

# %%
engine1 = create_engine("mysql+mysqlconnector://root:root@localhost/jotstar_db")

engine2 = create_engine("mysql+mysqlconnector://root:root@localhost/liocinema_db")

# %% [markdown]
# Fetch all the tables from both the databases and store it in the file

# %%
sql_query1 = "SELECT * FROM content_consumption"
Jotstar_content_consumption = pd.read_sql(sql_query1, engine1)
Jotstar_content_consumption

# %%
sql_query2 = "SELECT * FROM contents"
Jotstar_contents = pd.read_sql(sql_query2, engine1)
Jotstar_contents

# %%
sql_query3 = "SELECT * FROM subscribers"
Jotstar_subscribers = pd.read_sql(sql_query3, engine1)
Jotstar_subscribers

# %%
sql_query4 = "SELECT * FROM content_consumption"
liocinema_content_consumption = pd.read_sql(sql_query4, engine2)
liocinema_content_consumption

# %%
sql_query5 = "SELECT * FROM contents"
liocinema_contents= pd.read_sql(sql_query5, engine2)
liocinema_contents

# %%
sql_query6 = "SELECT * FROM subscribers"
liocinema_subscribers = pd.read_sql(sql_query6, engine2)
liocinema_subscribers

# %% [markdown]
# Save this dataframes as csv

# %%
# save all the dataframe as a csv files in the dataset

Jotstar_content_consumption.to_csv('datasets/Jotstar_content_consumption.csv',index = False)

Jotstar_contents.to_csv('datasets/Jotstar_contents.csv',index = False)

Jotstar_subscribers.to_csv('datasets/Jotstar_subscribers.csv',index = False)

liocinema_content_consumption.to_csv('datasets/liocinema_content_consumption.csv', index = False)

liocinema_contents.to_csv('datasets/liocinema_contents.csv', index = False)

liocinema_subscribers.to_csv('datasets/liocinema_subscribers.csv', index = False)

# %% [markdown]
# ## Access the dataset and performing EDA

# %%
Jotstar_content_consumption = pd.read_csv('datasets/Jotstar_content_consumption.csv')

Jotstar_contents = pd.read_csv('datasets/Jotstar_contents.csv')

Jotstar_subscribers = pd.read_csv('datasets/Jotstar_subscribers.csv')

Liocinema_content_consumption = pd.read_csv('datasets/liocinema_content_consumption.csv')

Liocinema_contents = pd.read_csv('datasets/liocinema_contents.csv')

Liocinema_subscribers = pd.read_csv('datasets/liocinema_subscribers.csv')

# %%
print('\t\t\t JOTSTAR CONTENT CONSUMPTION')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Jotstar_content_consumption.head()}')
print(f'\n\n\n Describe dataset: \n\n {Jotstar_content_consumption.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Jotstar_content_consumption.isnull().sum()}')
print(f'\n\n\n Dataset Info: \n\n {Jotstar_content_consumption.info()}')
# Out:
# 			 JOTSTAR CONTENT CONSUMPTION
#
#
#
#  Top 5 rows of dataset:
#
#             user_id device_type  total_watch_time_mins
# 0  UIDJS877cc0e02c9      Mobile                  14613
# 1  UIDJS06384e7ff06      Mobile                  13271
# 2  UIDJSc3997b7beb7      Mobile                   4644
# 3  UIDJS66726ce2325      Mobile                   5734
# 4  UIDJS040119b6107      Mobile                   2939
#
#
#
#  Describe dataset:
#
#         total_watch_time_mins
# count          133860.000000
# mean             7034.509331
# std              6342.440494
# min                66.000000
# 25%              2192.000000
# 50%              5154.000000
# 75%             10044.000000
# max             42635.000000
#
#
#
#  Null Values dataset:
#
#  user_id                  0
# device_type              0
# total_watch_time_mins    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133860 entries, 0 to 133859
# Data columns (total 3 columns):
# ...

# %%
print('\t\t\t JOTSTAR CONTENTS')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Jotstar_contents.head()}')
print(f'\n\n\n Describe dataset: \n\n {Jotstar_contents.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Jotstar_contents.isnull().sum()}')
print(f'\n\n\n Dataset Info: {Jotstar_contents.info()}')
# Out:
# 			 JOTSTAR CONTENTS
#
#
#
#  Top 5 rows of dataset:
#
#        content_id content_type language   genre  run_time
# 0  CJSMBEACT2e633        Movie  Bengali  Action        90
# 1  CJSMBEACT34aec        Movie  Bengali  Action       135
# 2  CJSMBEACT83b46        Movie  Bengali  Action       120
# 3  CJSMBECOM12e7a        Movie  Bengali  Comedy       120
# 4  CJSMBECOM5431a        Movie  Bengali  Comedy       135
#
#
#
#  Describe dataset:
#
#            run_time
# count  2360.000000
# mean     89.550847
# std      52.637611
# min       5.000000
# 25%      30.000000
# 50%      90.000000
# 75%     120.000000
# max     300.000000
#
#
#
#  Null Values dataset:
#
#  content_id      0
# content_type    0
# language        0
# genre           0
# run_time        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2360 entries, 0 to 2359
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
# ...

# %%
print('\t\t\t JOTSTAR SUBSCRIBERS')
print(f'\n\n\n {Jotstar_subscribers.info()}')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Jotstar_subscribers.head()}')
print(f'\n\n\n Describe dataset: \n\n {Jotstar_subscribers.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Jotstar_subscribers.isnull().sum()}')
# Out:
# 			 JOTSTAR SUBSCRIBERS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44620 entries, 0 to 44619
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                44620 non-null  object
#  1   age_group              44620 non-null  object
#  2   city_tier              44620 non-null  object
#  3   subscription_date      44620 non-null  object
#  4   subscription_plan      44620 non-null  object
#  5   last_active_date       6652 non-null   object
#  6   plan_change_date       7090 non-null   object
#  7   new_subscription_plan  7090 non-null   object
# dtypes: object(8)
# memory usage: 2.7+ MB
#
#
#
#  None
#
#
#
#  Top 5 rows of dataset:
#
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
# ...

# %%
print('\t\t\t LIOCINEMA SUBSCRIBERS')
print(f'\n\n\n {Liocinema_subscribers.info()}')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Liocinema_subscribers.head()}')
print(f'\n\n\n Describe dataset: \n\n {Liocinema_subscribers.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Liocinema_subscribers.isnull().sum()}')
# Out:
# 			 LIOCINEMA SUBSCRIBERS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183446 entries, 0 to 183445
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                183446 non-null  object
#  1   age_group              183446 non-null  object
#  2   city_tier              183446 non-null  object
#  3   subscription_date      183446 non-null  object
#  4   subscription_plan      183446 non-null  object
#  5   last_active_date       82305 non-null   object
#  6   plan_change_date       25014 non-null   object
#  7   new_subscription_plan  25014 non-null   object
# dtypes: object(8)
# memory usage: 11.2+ MB
#
#
#
#  None
#
#
#
#  Top 5 rows of dataset:
#
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDLC00000bea68a     25-34    Tier 3        2024-10-24              Free
# ...

# %%
print('\t\t\t LIOCINEMA CONTENTS')
print(f'\n\n\n Dataset Info: \n\n{Liocinema_contents.info()}')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Liocinema_contents.head()}')
print(f'\n\n\n Describe dataset: \n\n {Liocinema_contents.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Liocinema_contents.isnull().sum()}')
# Out:
# 			 LIOCINEMA CONTENTS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   content_id    1250 non-null   object
#  1   content_type  1250 non-null   object
#  2   language      1250 non-null   object
#  3   genre         1250 non-null   object
#  4   run_time      1250 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 49.0+ KB
#
#
#
#  Dataset Info:
#
# None
#
#
#
#  Top 5 rows of dataset:
#
#        content_id content_type language   genre  run_time
# 0  CLCMENACT6b77e        Movie  English  Action       120
# 1  CLCMENACTb7ceb        Movie  English  Action       135
# 2  CLCMENCOM1563a        Movie  English  Comedy       135
# 3  CLCMENCOM16d2c        Movie  English  Comedy       135
# 4  CLCMENCOMa0548        Movie  English  Comedy       135
#
#
#
#  Describe dataset:
#
#            run_time
# count  1250.000000
# ...

# %%
print('\t\t\t LIOCINEMA CONTENT CONSUMPTION')
print(f'\n\n\n Top 5 rows of dataset: \n\n{Liocinema_content_consumption.head()}')
print(f'\n\n\n Describe dataset: \n\n {Liocinema_content_consumption.describe()}')
print(f'\n\n\n Null Values dataset: \n\n {Liocinema_content_consumption.isnull().sum()}')
print(f'\n\n\n Dataset Info: \n\n {Liocinema_content_consumption.info()}')
# Out:
# 			 LIOCINEMA CONTENT CONSUMPTION
#
#
#
#  Top 5 rows of dataset:
#
#             user_id device_type  total_watch_time_mins
# 0  UIDLC459c98ee486      Mobile                    502
# 1  UIDLCe4b2fd90790      Mobile                   2098
# 2  UIDLCbc8f0a05367      Mobile                    557
# 3  UIDLC9fc67130445      Mobile                   1720
# 4  UIDLC7026c3e0374      Mobile                    908
#
#
#
#  Describe dataset:
#
#         total_watch_time_mins
# count          430752.000000
# mean             1536.829517
# std              2722.600651
# min                 5.000000
# 25%               223.000000
# 50%               580.000000
# 75%              1490.000000
# max             39966.000000
#
#
#
#  Null Values dataset:
#
#  user_id                  0
# device_type              0
# total_watch_time_mins    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430752 entries, 0 to 430751
# Data columns (total 3 columns):
# ...
